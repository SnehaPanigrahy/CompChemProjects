# %%
from rdkit.Chem import Draw
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.ML.Descriptors import MoleculeDescriptors

# %%
import pandas as pd
import numpy as np
from mordred import descriptors,Calculator

# %%
Simvastatin = Chem.MolFromSmiles('O=C(O[C@@H]1[C@H]3C(=C/[C@H](C)C1)\C=C/[C@@H]([C@@H]3CC[C@H]2OC(=O)C[C@H](O)C2)C)C(C)(C)CC')
Draw.MolToImage(Simvastatin, size = (500, 450))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x450>

# %%
Descriptors.MolWt(Simvastatin)
# Out:
# 418.57400000000024

# %%
Lovastatin = Chem.MolFromSmiles('O=C(O[C@@H]1[C@H]3C(=C/[C@H](C)C1)\C=C/[C@@H]([C@@H]3CC[C@H]2OC(=O)C[C@H](O)C2)C)[C@@H](C)CC')
Draw.MolToImage(Lovastatin, size= (500, 500))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500>

# %%
Descriptors.MolWt(Lovastatin)
# Out:
# 404.5470000000002

# %%
C2H6 = Chem.MolFromSmiles('CC')
Draw.MolToImage(C2H6, size = (50,50))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=50x50>

# %%
benzene = Chem.MolFromSmiles('c1ccccc1')
Draw.MolToImage(benzene, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
hexane = Chem.MolFromSmiles('C1CCCCC1')
Draw.MolToImage(hexane, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
OH_neg = Chem.MolFromSmiles('[OH-]')
Draw.MolToImage(OH_neg, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
OH_pos = Chem.MolFromSmiles('[OH+]')
Draw.MolToImage(OH_pos, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
oxide = Chem.MolFromSmiles('[O-2]')
Draw.MolToImage(oxide, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
H2 = Chem.MolFromSmiles('[H][H]')
Draw.MolToImage(H2, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
ethanol = Chem.MolFromSmiles('CCO')
Draw.MolToImage(ethanol, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
one_butene = Chem.MolFromSmiles('C=CCC')
Draw.MolToImage(one_butene, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
acetylene = Chem.MolFromSmiles('C#C')
Draw.MolToImage(acetylene, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
aniline = Chem.MolFromSmiles('C1:C:C:C:C:C1:N')
Draw.MolToImage(aniline, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
benzene = Chem.MolFromSmiles('c1ccccc1N')
Draw.MolToImage(benzene, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
neo_pentane = Chem.MolFromSmiles('CC(C)(C)C')
Draw.MolToImage(neo_pentane, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
acetone = Chem.MolFromSmiles('CC(=O)C')
Draw.MolToImage(acetone, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
aliphatic = Chem.MolFromSmiles('C3CCC3')
Draw.MolToImage(aliphatic, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
bicyclic = Chem.MolFromSmiles('C1(CN)C2CCCC2C1')
Draw.MolToImage(bicyclic, size = (100,100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
cis_2_butene = Chem.MolFromSmiles('C/C=C\C')
Draw.MolToImage(cis_2_butene, size=(100, 100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
trans_2_butene = Chem.MolFromSmiles('C\C=C\C')
Draw.MolToImage(trans_2_butene, size=(100, 100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
sodim_chloride = Chem.MolFromSmiles('[Na+].[Cl-]')
Draw.MolToImage(sodim_chloride, size=(100, 100))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x100>

# %%
R_alanine = Chem.MolFromSmiles('C[C@H](C(=O)O)N')
Draw.MolToImage(R_alanine, size=(150,150))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150>

# %%
S_alanine = Chem.MolFromSmiles('C[C@@H](C(=O)O)N')
Draw.MolToImage(S_alanine, size=(150,150))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150>

# %%
S_2_chlorobutane = Chem.MolFromSmiles('C[C@@H](Cl)CC')
Draw.MolToImage(S_2_chlorobutane, size=(150,150))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150>

# %%
S_2_chlorobutane = Chem.MolFromSmiles('C[C@H](Cl)CC')
Draw.MolToImage(S_2_chlorobutane, size=(150,150))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150>

# %%
methyl_chloride = Chem.MolFromSmiles('C[Cl]')
Draw.MolToImage(methyl_chloride, size=(200,200))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
sulf_hex = Chem.MolFromSmiles('FS(F)(F)(F)(F)(F)')
Draw.MolToImage(sulf_hex, size=(200,200))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
ethanoic_acid = Chem.MolFromSmiles('CC(=O)O')
Draw.MolToImage(ethanoic_acid, size = (200,200))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
ethanol = Chem.MolFromSmiles('CC(O)')
Draw.MolToImage(ethanol, size = (200, 200))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
Formic_acid = Chem.MolFromSmiles('C(=O)(O)')
Draw.MolToImage(Formic_acid, size = (200, 200))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
Decalin = Chem.MolFromSmiles('C1C2CCCC2CC1')
Draw.MolToImage(Decalin, size = (200, 200))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
Napthalene = Chem.MolFromSmiles('c1c2ccccc2ccc1')
Draw.MolToImage(Napthalene, size = (200, 200))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>
